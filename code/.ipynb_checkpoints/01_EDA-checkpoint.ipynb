# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

plt.rcParams['figure.figsize'] = (20, 9)
plt.rcParams.update({'font.size': 16})
sns.set_style("whitegrid")

# %%
df = pd.read_csv('../data/NASA-asteroid-classification.csv')

# %%
df.head()
# Out:
#                     full_name       name neo pha   epoch_cal equinox  \
# 0          433 Eros (1898 DQ)       Eros   Y   N  20200531.0   J2000
# 1      588 Achilles (1906 TG)   Achilles   N   N  20200531.0   J2000
# 2     617 Patroclus (1906 VY)  Patroclus   N   N  20200531.0   J2000
# 3        624 Hektor (1907 XM)     Hektor   N   N  20200531.0   J2000
# 4        659 Nestor (1908 CS)     Nestor   N   N  20200531.0   J2000
#
#           e         a         q          i  ...  t_jup          om  \
# 0  0.222951  1.458046  1.132973  10.830543  ...  4.582  304.299327
# 1  0.147122  5.209394  4.442980  10.319724  ...  2.946  316.536049
# 2  0.138967  5.214560  4.489910  22.051776  ...  2.836   44.348414
# 3  0.022797  5.262260  5.142298  18.157697  ...  2.899  342.791035
# 4  0.117448  5.164464  4.557910   4.522630  ...  2.980  350.739111
#
#            per      per_y  class      producer   first_obs    last_obs  \
# 0   643.065402   1.760617    AMO      Giorgini  1893-10-29  2019-02-13
# 1  4342.893776  11.890195    TJN    Otto Matic  1906-02-22  2020-01-06
# 2  4349.355185  11.907886    TJN  Ryan S. Park  1998-04-22  2019-08-17
# 3  4409.170054  12.071650    TJN    Otto Matic  1907-02-11  2020-01-26
# 4  4286.830857  11.736703    TJN    Otto Matic  1908-03-23  2020-01-06
#
#    diameter  albedo
# 0    16.840   0.250
# 1   130.099   0.043
# 2   140.362   0.047
# 3   225.000   0.025
# 4   112.320   0.035
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (7856, 26)

# %%
# Check if there are null values
df.isnull().sum()
# Out:
# full_name       0
# name         7442
# neo             0
# pha             0
# epoch_cal       0
# equinox         0
# e               0
# a               0
# q               0
# i               0
# w               0
# H               0
# ma              0
# ad              0
# n               0
# moid            0
# t_jup           0
# om              0
# per             0
# per_y           0
# class           0
# producer        0
# first_obs       0
# last_obs        0
# diameter     5442
# albedo       5475
# dtype: int64

# %%
df.columns
# Out:
# Index(['full_name', 'name', 'neo', 'pha', 'epoch_cal', 'equinox', 'e', 'a',
#        'q', 'i', 'w', 'H', 'ma', 'ad', 'n', 'moid', 't_jup', 'om', 'per',
#        'per_y', 'class', 'producer', 'first_obs', 'last_obs', 'diameter',
#        'albedo'],
#       dtype='object')

# %%
# Create column name dictionary to rename columns
column_names = {
    'pha': 'hazardous',
    'e': 'eccentricity_(e)',
    'a': 'semi_major_axis_(a)',
    'q': 'perihelion_dist_(q)',
    'i': 'inclination_(i)',
    'w': 'perihelion_arg_(w)',
    'H': 'abs_magnitude_(H)',
    'ma': 'mean_anomaly',
    'ad': 'aphelion_dist_(Q)',
    'n': 'mean_motion_(n)',
    'moid': 'min_orbit_intersection_dist',
    't_jup': 't_jupiter',
    'per': 'orbital_per_(d)',
    'per_y': 'orbital_per_(y)',
    'om': 'asc_node_long_(deg)',
    'diameter': 'diameter_(km)'
}

# Rename columns
df.rename(columns=column_names, inplace=True)

# %%
# Drop name column because it's a repitition of full_name column but with most values missing
# Drop producer because it's unbalanced and won't contribute to the model 
# Drop equinox because all observations have the same equinox 'J2000'
df.drop(columns=['name', 'producer', 'equinox'], inplace=True)

# Verify there are no more missing values
df.isnull().sum()
# Out:
# full_name                         0
# neo                               0
# hazardous                         0
# epoch_cal                         0
# eccentricity_(e)                  0
# semi_major_axis_(a)               0
# perihelion_dist_(q)               0
# inclination_(i)                   0
# perihelion_arg_(w)                0
# abs_magnitude_(H)                 0
# mean_anomaly                      0
# aphelion_dist_(Q)                 0
# mean_motion_(n)                   0
# min_orbit_intersection_dist       0
# t_jupiter                         0
# asc_node_long_(deg)               0
# orbital_per_(d)                   0
# orbital_per_(y)                   0
# class                             0
# first_obs                         0
# last_obs                          0
# diameter_(km)                  5442
# albedo                         5475
# dtype: int64

# %%
# Inspect the data types
df.dtypes
# Out:
# full_name                       object
# neo                             object
# hazardous                       object
# epoch_cal                      float64
# eccentricity_(e)               float64
# semi_major_axis_(a)            float64
# perihelion_dist_(q)            float64
# inclination_(i)                float64
# perihelion_arg_(w)             float64
# abs_magnitude_(H)              float64
# mean_anomaly                   float64
# aphelion_dist_(Q)              float64
# mean_motion_(n)                float64
# min_orbit_intersection_dist    float64
# t_jupiter                      float64
# asc_node_long_(deg)            float64
# orbital_per_(d)                float64
# orbital_per_(y)                float64
# class                           object
# first_obs                       object
# last_obs                        object
# diameter_(km)                  float64
# albedo                         float64
# dtype: object

# %%
df.head()
# Out:
#                     full_name neo hazardous   epoch_cal  eccentricity_(e)  \
# 0          433 Eros (1898 DQ)   Y         N  20200531.0          0.222951
# 1      588 Achilles (1906 TG)   N         N  20200531.0          0.147122
# 2     617 Patroclus (1906 VY)   N         N  20200531.0          0.138967
# 3        624 Hektor (1907 XM)   N         N  20200531.0          0.022797
# 4        659 Nestor (1908 CS)   N         N  20200531.0          0.117448
#
#    semi_major_axis_(a)  perihelion_dist_(q)  inclination_(i)  \
# 0             1.458046             1.132973        10.830543
# 1             5.209394             4.442980        10.319724
# 2             5.214560             4.489910        22.051776
# 3             5.262260             5.142298        18.157697
# 4             5.164464             4.557910         4.522630
#
#    perihelion_arg_(w)  abs_magnitude_(H)  ...  min_orbit_intersection_dist  \
# 0          178.882294               10.4  ...                     0.148623
# 1          133.308510                8.3  ...                     3.470060
# 2          307.866082                8.2  ...                     3.537570
# 3          184.243883                7.2  ...                     4.149850
# 4          343.462149                8.7  ...                     3.548340
#
#    t_jupiter  asc_node_long_(deg)  orbital_per_(d)  orbital_per_(y)  class  \
# 0      4.582           304.299327       643.065402         1.760617    AMO
# 1      2.946           316.536049      4342.893776        11.890195    TJN
# 2      2.836            44.348414      4349.355185        11.907886    TJN
# 3      2.899           342.791035      4409.170054        12.071650    TJN
# 4      2.980           350.739111      4286.830857        11.736703    TJN
#
#     first_obs    last_obs diameter_(km) albedo
# 0  1893-10-29  2019-02-13        16.840  0.250
# 1  1906-02-22  2020-01-06       130.099  0.043
# 2  1998-04-22  2019-08-17       140.362  0.047
# 3  1907-02-11  2020-01-26       225.000  0.025
# 4  1908-03-23  2020-01-06       112.320  0.035
#
# [5 rows x 23 columns]

# %%
# Convert datetime columns to pandas datetime data types 
df['first_obs'] = pd.to_datetime(df['first_obs'], unit='D')
df['last_obs'] = pd.to_datetime(df['last_obs'], unit='D')

# Check that it worked
df.dtypes
# Out:
# neo                                     int64
# hazardous                               int64
# epoch_cal                             float64
# eccentricity_(e)                      float64
# semi_major_axis_(a)                   float64
# perihelion_dist_(q)                   float64
# inclination_(i)                       float64
# perihelion_arg_(w)                    float64
# abs_magnitude_(H)                     float64
# mean_anomaly                          float64
# aphelion_dist_(Q)                     float64
# mean_motion_(n)                       float64
# min_orbit_intersection_dist           float64
# t_jupiter                             float64
# asc_node_long_(deg)                   float64
# orbital_per_(d)                       float64
# orbital_per_(y)                       float64
# class                                  object
# first_obs                      datetime64[ns]
# last_obs                       datetime64[ns]
# stand_grav_param                      float64
# rel_velocity_Q                        float64
# rel_velocity_q                        float64
# dtype: object

# %%
# Assign target labels (hazardous)
# Assign NEO labels
df['hazardous'] = df['hazardous'].map({'Y': 1, 'N': 0})
df['neo'] = df['neo'].map({'Y': 1, 'N': 0})

df['hazardous'].value_counts()
# Out:
# 0    7093
# 1     763
# Name: hazardous, dtype: int64

# %%
df['neo'].value_counts()
# Out:
# 0    4945
# 1    2911
# Name: neo, dtype: int64

# %%
df.dtypes
# Out:
# full_name                              object
# neo                                     int64
# hazardous                               int64
# epoch_cal                             float64
# eccentricity_(e)                      float64
# semi_major_axis_(a)                   float64
# perihelion_dist_(q)                   float64
# inclination_(i)                       float64
# perihelion_arg_(w)                    float64
# abs_magnitude_(H)                     float64
# mean_anomaly                          float64
# aphelion_dist_(Q)                     float64
# mean_motion_(n)                       float64
# min_orbit_intersection_dist           float64
# t_jupiter                             float64
# asc_node_long_(deg)                   float64
# orbital_per_(d)                       float64
# orbital_per_(y)                       float64
# class                                  object
# first_obs                      datetime64[ns]
# last_obs                       datetime64[ns]
# diameter_(km)                         float64
# albedo                                float64
# dtype: object

# %%
df['class'].value_counts()
# Out:
# TJN    4945
# APO    1473
# AMO    1201
# ATE     237
# Name: class, dtype: int64

# %%
# get dummies for each asteroid class
# AMO was dropped
# df = pd.get_dummies(df, columns=['class'], drop_first=True)

# %%
df.head()
# Out:
#                     full_name  neo  hazardous   epoch_cal  eccentricity_(e)  \
# 0          433 Eros (1898 DQ)    1          0  20200531.0          0.222951
# 1      588 Achilles (1906 TG)    0          0  20200531.0          0.147122
# 2     617 Patroclus (1906 VY)    0          0  20200531.0          0.138967
# 3        624 Hektor (1907 XM)    0          0  20200531.0          0.022797
# 4        659 Nestor (1908 CS)    0          0  20200531.0          0.117448
#
#    semi_major_axis_(a)  perihelion_dist_(q)  inclination_(i)  \
# 0             1.458046             1.132973        10.830543
# 1             5.209394             4.442980        10.319724
# 2             5.214560             4.489910        22.051776
# 3             5.262260             5.142298        18.157697
# 4             5.164464             4.557910         4.522630
#
#    perihelion_arg_(w)  abs_magnitude_(H)  ...  min_orbit_intersection_dist  \
# 0          178.882294               10.4  ...                     0.148623
# 1          133.308510                8.3  ...                     3.470060
# 2          307.866082                8.2  ...                     3.537570
# 3          184.243883                7.2  ...                     4.149850
# 4          343.462149                8.7  ...                     3.548340
#
#    t_jupiter  asc_node_long_(deg)  orbital_per_(d)  orbital_per_(y)  class  \
# 0      4.582           304.299327       643.065402         1.760617    AMO
# 1      2.946           316.536049      4342.893776        11.890195    TJN
# 2      2.836            44.348414      4349.355185        11.907886    TJN
# 3      2.899           342.791035      4409.170054        12.071650    TJN
# 4      2.980           350.739111      4286.830857        11.736703    TJN
#
#    first_obs   last_obs diameter_(km) albedo
# 0 1893-10-29 2019-02-13        16.840  0.250
# 1 1906-02-22 2020-01-06       130.099  0.043
# 2 1998-04-22 2019-08-17       140.362  0.047
# 3 1907-02-11 2020-01-26       225.000  0.025
# 4 1908-03-23 2020-01-06       112.320  0.035
#
# [5 rows x 23 columns]

# %% [markdown]
# [Astronomical Unit](https://cneos.jpl.nasa.gov/glossary/au.html)
# [Lunar Distance](https://cneos.jpl.nasa.gov/glossary/LD.html)
# [True Anomoly](https://cneos.jpl.nasa.gov/glossary/true_anomaly.html)
# [Perihelion](https://cneos.jpl.nasa.gov/glossary/perihelion.html)
# [Absolute Magnitude](https://cneos.jpl.nasa.gov/glossary/h.html)
# [Jupiter Tisserand Invariant](https://pdssbn.astro.umd.edu/about/what_r_sb.shtml)
# [Tisserand Parameter](http://www2.ess.ucla.edu/~jewitt/tisserand.html)
#
# >\begin{equation}
# T_J = \frac{a_J}{a} + 2 \left[(1 - e^2)\frac{a}{a_J}\right]^{1/2} \cos(i)
# \end{equation}
#
# [Mean Anomaly](http://www.columbia.edu/~my2317/asteroidproject.html)
# [Epoch](https://en.wikipedia.org/wiki/Epoch_(astronomy))

# %% [markdown]
# https://cneos.jpl.nasa.gov/sentry/intro.html
# https://pdssbn.astro.umd.edu/about/what_r_sb.shtml

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (10,10), dpi = 90) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    colors = ['#7F7FFF', '#7F7FFF', '#7F7FFF', '#7F7FFF']
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], color = colors[i]) # feel free to add more settings
        # Set titles, labels, etc for each subplot
    for i, title in enumerate(list_of_titles):
        ax[i].set(title=f'{title} Histogram')
    for i, xlabel in enumerate(list_of_xlabels):
        ax[i].set(xlabel=xlabel)
    plt.subplots_adjust(hspace=0.3)
    
#     '#7F7FFF', '#FCBFB8', '#7F7FFF', '#FCBFB8'

# %%
subplot_histograms(df,
                   ['neo', 'hazardous', 'epoch_cal', 'eccentricity_(e)'],
                   ['neo', 'hazardous', 'epoch_cal', 'eccentricity_(e)'],
                   ['neo', 'hazardous', 'epoch_cal', 'eccentricity_(e)']
                  )

# %%
subplot_histograms(df,
                   ['semi_major_axis_(a)', 'perihelion_dist_(q)', 'inclination_(i)', 'perihelion_arg_(w)'],
                   ['semi_major_axis_(a)', 'perihelion_dist_(q)', 'inclination_(i)', 'perihelion_arg_(w)'],
                   ['semi_major_axis_(a)', 'perihelion_dist_(q)', 'inclination_(i)', 'perihelion_arg_(w)']
                  )

# %%
subplot_histograms(df,
                  ['abs_magnitude_(H)', 'mean_anomaly', 'aphelion_dist_(Q)', 'mean_motion_(n)'],
                  ['abs_magnitude_(H)', 'mean_anomaly', 'aphelion_dist_(Q)', 'mean_motion_(n)'],
                  ['abs_magnitude_(H)', 'mean_anomaly', 'aphelion_dist_(Q)', 'mean_motion_(n)']
                  )

# %%
subplot_histograms(df,
                  ['min_orbit_intersection_dist', 't_jupiter', 'asc_node_long_(deg)', 'diameter_(km)'],
                  ['min_orbit_intersection_dist', 't_jupiter', 'asc_node_long_(deg)', 'diameter_(km)'],
                  ['min_orbit_intersection_dist', 't_jupiter', 'asc_node_long_(deg)', 'diameter_(km)'])
# Out:
# /Users/mariaflores/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/mariaflores/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
subplot_histograms(df,
                  ['orbital_per_(d)', 'orbital_per_(y)'],
                  ['orbital_per_(d)', 'orbital_per_(y)'],
                  ['orbital_per_(d)', 'orbital_per_(y)'])

# %%
df_numeric = df.describe().columns

# %%
df[df_numeric].shape
# Out:
# (7856, 19)

# %%
len(df_numeric)
# Out:
# 19

# %%
plt.tight_layout(pad=0.9)
plt.figure(figsize=(35,30)) 
plt.subplots_adjust(wspace = 0.2)
nbr_columns = 4 
nbr_graphs = len(df_numeric) 
nbr_rows = int(np.ceil(nbr_graphs/nbr_columns)) 
columns = list(df[df_numeric].columns.values) 
for i in range(0,len(columns)-1): 
    plt.subplot(nbr_rows,nbr_columns,i+1) 
    ax1=sns.boxplot(x= columns[i], data= df[df_numeric], orient="h") 
plt.show();

# %%
df.groupby('hazardous')['class'].value_counts().plot(kind='barh');

# %%
df.sort_values(by='hazardous')['class'].value_counts().plot(kind='barh');

# %%
def plot_scatterplot(dataframe, list_of_columns, title, xlabel, ylabel):
    plt.figure(figsize=(8, 5), dpi=80)
    plt.scatter(dataframe[list_of_columns[0]],
            dataframe[list_of_columns[1]], c= '#7F7FFF')
    plt.title(title, fontsize=18)
    plt.xlabel(xlabel, fontsize = 12)
    plt.ylabel(ylabel, fontsize=12);

# %%
# sns.pairplot(df);

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='coolwarm')

# %%
df.head()
# Out:
#                     full_name  neo  hazardous   epoch_cal  eccentricity_(e)  \
# 0          433 Eros (1898 DQ)    1          0  20200531.0          0.222951
# 1      588 Achilles (1906 TG)    0          0  20200531.0          0.147122
# 2     617 Patroclus (1906 VY)    0          0  20200531.0          0.138967
# 3        624 Hektor (1907 XM)    0          0  20200531.0          0.022797
# 4        659 Nestor (1908 CS)    0          0  20200531.0          0.117448
#
#    semi_major_axis_(a)  perihelion_dist_(q)  inclination_(i)  \
# 0             1.458046             1.132973        10.830543
# 1             5.209394             4.442980        10.319724
# 2             5.214560             4.489910        22.051776
# 3             5.262260             5.142298        18.157697
# 4             5.164464             4.557910         4.522630
#
#    perihelion_arg_(w)  abs_magnitude_(H)  ...  min_orbit_intersection_dist  \
# 0          178.882294               10.4  ...                     0.148623
# 1          133.308510                8.3  ...                     3.470060
# 2          307.866082                8.2  ...                     3.537570
# 3          184.243883                7.2  ...                     4.149850
# 4          343.462149                8.7  ...                     3.548340
#
#    t_jupiter  asc_node_long_(deg)  orbital_per_(d)  orbital_per_(y)  class  \
# 0      4.582           304.299327       643.065402         1.760617    AMO
# 1      2.946           316.536049      4342.893776        11.890195    TJN
# 2      2.836            44.348414      4349.355185        11.907886    TJN
# 3      2.899           342.791035      4409.170054        12.071650    TJN
# 4      2.980           350.739111      4286.830857        11.736703    TJN
#
#    first_obs   last_obs diameter_(km) albedo
# 0 1893-10-29 2019-02-13        16.840  0.250
# 1 1906-02-22 2020-01-06       130.099  0.043
# 2 1998-04-22 2019-08-17       140.362  0.047
# 3 1907-02-11 2020-01-26       225.000  0.025
# 4 1908-03-23 2020-01-06       112.320  0.035
#
# [5 rows x 23 columns]

# %%
# plt.figure(figsize=(12,8))
# plt.plot(df1)

# %%
# Make copy of df to set first observed as index
df1 = df.copy()
df1.set_index('first_obs', inplace=True)

# Make copy of df to set last observed as index
df2 = df.copy()
df2.set_index('last_obs', inplace=True)

# %%
df1['abs_magnitude_(H)'].plot();

# %%
df2['abs_magnitude_(H)'].plot();

# %%
df.groupby('first_obs')[['neo']].count().plot();

# %%
df1['neo'].resample('Y').sum().plot();

# %%
df2['neo'].resample('Y').sum().plot();

# %%
df1[['neo']].resample('Y').sum().describe()
# Out:
#               neo
# count  125.000000
# mean    23.288000
# std     49.371177
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%     21.000000
# max    285.000000

# %%
df1['neo'].resample('Y').sum()
# Out:
# first_obs
# 1893-12-31     1
# 1894-12-31     0
# 1895-12-31     0
# 1896-12-31     0
# 1897-12-31     0
#               ..
# 2013-12-31    34
# 2014-12-31    31
# 2015-12-31    21
# 2016-12-31     8
# 2017-12-31     1
# Freq: A-DEC, Name: neo, Length: 125, dtype: int64

# %%
labels = list(df1.index.year.values)
len(labels)
# Out:
# 7856

# %%
plt.figure(figsize=(22,10))
df1['neo'].sort_values().resample('Y').sum().tail(30).plot(kind='bar', grid=False)
plt.title('Near Earth Objects (Date First Observed)')
plt.ylabel('Total')
# Out:
# Text(0, 0.5, 'Total')

# %%
plt.figure(figsize=(22,10))
df1['neo'].sort_values().resample('Y').sum().tail(30).plot(kind='bar', grid=False)
plt.title('Near Earth Objects (Date First Observed)')
plt.ylabel('Total')
plt.xticks(ticks = np.arange(30), labels=labels, rotation = 'horizontal');

# %%
df2['neo'].resample('Y').sum().plot(kind='bar', grid=False)
plt.title('Near Earth Objects (Date Last Observed)')
plt.ylabel('Total');

# %%
df.sort_values(by='hazardous')['first_obs'].value_counts().plot();

# %% [markdown]
# ### Orbital Elements
#
#
#
# ![orbitalelements](../images/orbitalelements.png)
# [source](http://www.columbia.edu/~my2317/asteroidproject.html)

# %%
df.dtypes
# Out:
# full_name                              object
# neo                                     int64
# hazardous                               int64
# epoch_cal                             float64
# eccentricity_(e)                      float64
# semi_major_axis_(a)                   float64
# perihelion_dist_(q)                   float64
# inclination_(i)                       float64
# perihelion_arg_(w)                    float64
# abs_magnitude_(H)                     float64
# mean_anomaly                          float64
# aphelion_dist_(Q)                     float64
# mean_motion_(n)                       float64
# min_orbit_intersection_dist           float64
# t_jupiter                             float64
# asc_node_long_(deg)                   float64
# orbital_per_(d)                       float64
# orbital_per_(y)                       float64
# class                                  object
# first_obs                      datetime64[ns]
# last_obs                       datetime64[ns]
# diameter_(km)                         float64
# albedo                                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# full_name                         0
# neo                               0
# hazardous                         0
# epoch_cal                         0
# eccentricity_(e)                  0
# semi_major_axis_(a)               0
# perihelion_dist_(q)               0
# inclination_(i)                   0
# perihelion_arg_(w)                0
# abs_magnitude_(H)                 0
# mean_anomaly                      0
# aphelion_dist_(Q)                 0
# mean_motion_(n)                   0
# min_orbit_intersection_dist       0
# t_jupiter                         0
# asc_node_long_(deg)               0
# orbital_per_(d)                   0
# orbital_per_(y)                   0
# class                             0
# first_obs                         0
# last_obs                          0
# diameter_(km)                  5442
# albedo                         5475
# dtype: int64

# %%
sns.boxplot(x=df['semi_major_axis_(a)'], data=df)

# %% [markdown]
# ### Finding Standard Gravitational Parameter
# ---
#
# **Formula:**
# $\mu = \frac{4\pi^2a^3}{T^2}$
#
#
# Defines a function that takes the inputs $a$ (the semi-major axis) and $T$ (the orbital period in years) to find the standard gravitational parameter.

# %%
import math
# Function to calculate standard gravitational parameter in order 
# to find the relative velocity of an asteroid given the semi-major axis and the orbital period
# result will be in au/yr

def stand_grav_param(a, T, df):
    stand_grav_param_list = []
    for i in a:
        for t in T:
            stand_grav_param = (4 * (math.pi**2) * (i**3)) / (t**2)
        stand_grav_param_list.append(stand_grav_param)
    df['stand_grav_param'] = stand_grav_param_list
    return df['stand_grav_param']

# %%
stand_grav_param(df['semi_major_axis_(a)'], df['orbital_per_(y)'], df)
# Out:
# 0        0.818917
# 1       37.349792
# 2       37.461014
# 3       38.498470
# 4       36.391711
#           ...
# 7851    36.638868
# 7852    39.627872
# 7853     2.331388
# 7854    37.607843
# 7855    39.476926
# Name: stand_grav_param, Length: 7856, dtype: float64

# %%
# View a quick distribution
sns.distplot(df['stand_grav_param'])

# %% [markdown]
# ### Finding Instantaneous Orbit Velocity
#
# ---
# **Formula:**
# $v$ = $\mu\sqrt{{\frac{2}{r}}-{\frac{1}{a}}}$
#
#
# Create function that will take the $r$ (the orbital distance from the sun), $a$ (the semi-major axis), and `stand_grav_param` (the standard gravitational parameter calculated above).

# %%
# Create a function to calculate the instantaneous velocity
# Result in AU/year

def calc_velocity(r, a, stand_grav_param):
    velocity = (stand_grav_param * ((2/r) - (1/a)))**.5
    return velocity

# %%
# Apply the function to find the velocity given the semimajor axis and the farthest distance from the Sun
df['rel_velocity_Q'] = calc_velocity(df['aphelion_dist_(Q)'], df['semi_major_axis_(a)'], df['stand_grav_param'])

# Apply the function to find the velocity given the semimajor axis and the closest distance from the Sun
df['rel_velocity_q'] = calc_velocity(df['perihelion_dist_(q)'], df['semi_major_axis_(a)'], df['stand_grav_param'])

# Current units AU/yr
# Convert to km/sec
df['rel_velocity_Q'] = df['rel_velocity_Q'] * 4.74372
df['rel_velocity_q'] = df['rel_velocity_q'] * 4.74372

# %%
df.head()
# Out:
#                     full_name  neo  hazardous   epoch_cal  eccentricity_(e)  \
# 0          433 Eros (1898 DQ)    1          0  20200531.0          0.222951
# 1      588 Achilles (1906 TG)    0          0  20200531.0          0.147122
# 2     617 Patroclus (1906 VY)    0          0  20200531.0          0.138967
# 3        624 Hektor (1907 XM)    0          0  20200531.0          0.022797
# 4        659 Nestor (1908 CS)    0          0  20200531.0          0.117448
#
#    semi_major_axis_(a)  perihelion_dist_(q)  inclination_(i)  \
# 0             1.458046             1.132973        10.830543
# 1             5.209394             4.442980        10.319724
# 2             5.214560             4.489910        22.051776
# 3             5.262260             5.142298        18.157697
# 4             5.164464             4.557910         4.522630
#
#    perihelion_arg_(w)  abs_magnitude_(H)  ...  orbital_per_(d)  \
# 0          178.882294               10.4  ...       643.065402
# 1          133.308510                8.3  ...      4342.893776
# 2          307.866082                8.2  ...      4349.355185
# 3          184.243883                7.2  ...      4409.170054
# 4          343.462149                8.7  ...      4286.830857
#
#    orbital_per_(y)  class  first_obs   last_obs  diameter_(km)  albedo  \
# 0         1.760617    AMO 1893-10-29 2019-02-13         16.840   0.250
# 1        11.890195    TJN 1906-02-22 2020-01-06        130.099   0.043
# 2        11.907886    TJN 1998-04-22 2019-08-17        140.362   0.047
# 3        12.071650    TJN 1907-02-11 2020-01-26        225.000   0.025
# 4        11.736703    TJN 1908-03-23 2020-01-06        112.320   0.035
#
#    stand_grav_param rel_velocity_Q rel_velocity_q
# 0          0.818917       2.833825       4.459991
# 1         37.349792      10.952378      14.730948
# 2         37.461014      11.054892      14.623303
# 3         38.498470      12.541588      13.126737
# 4         36.391711      11.190881      14.169385
#
# [5 rows x 26 columns]

# %% [markdown]
# Compares the distribution between the relative orbital velocity from the **aphelion distance** (the farthest distance to the sun) and the **perihelion distance** (the closest distance to the sun).

# %% [markdown]
# ![orbitalelements](../images/orbit_ellipse1.gif)
# [source](https://calgary.rasc.ca/orbits.htm)

# %%
sns.distplot(df['rel_velocity_Q'])
sns.distplot(df['rel_velocity_q']);

# %%
df['rel_velocity_Q'].describe()
# Out:
# count    7856.000000
# mean        8.361879
# std         4.543697
# min         0.502246
# 25%         2.930712
# 50%        11.470105
# 75%        11.973874
# max        12.927959
# Name: rel_velocity_Q, dtype: float64

# %%
df['rel_velocity_q'].describe()
# Out:
# count    7856.000000
# mean       11.461269
# std         3.853916
# min         2.427772
# 25%         8.730679
# 50%        13.263855
# 75%        13.785724
# max        49.817166
# Name: rel_velocity_q, dtype: float64

# %%
df.dtypes
# Out:
# full_name                              object
# neo                                     int64
# hazardous                               int64
# epoch_cal                             float64
# eccentricity_(e)                      float64
# semi_major_axis_(a)                   float64
# perihelion_dist_(q)                   float64
# inclination_(i)                       float64
# perihelion_arg_(w)                    float64
# abs_magnitude_(H)                     float64
# mean_anomaly                          float64
# aphelion_dist_(Q)                     float64
# mean_motion_(n)                       float64
# min_orbit_intersection_dist           float64
# t_jupiter                             float64
# asc_node_long_(deg)                   float64
# orbital_per_(d)                       float64
# orbital_per_(y)                       float64
# class                                  object
# first_obs                      datetime64[ns]
# last_obs                       datetime64[ns]
# diameter_(km)                         float64
# albedo                                float64
# stand_grav_param                      float64
# rel_velocity_Q                        float64
# rel_velocity_q                        float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# full_name                         0
# neo                               0
# hazardous                         0
# epoch_cal                         0
# eccentricity_(e)                  0
# semi_major_axis_(a)               0
# perihelion_dist_(q)               0
# inclination_(i)                   0
# perihelion_arg_(w)                0
# abs_magnitude_(H)                 0
# mean_anomaly                      0
# aphelion_dist_(Q)                 0
# mean_motion_(n)                   0
# min_orbit_intersection_dist       0
# t_jupiter                         0
# asc_node_long_(deg)               0
# orbital_per_(d)                   0
# orbital_per_(y)                   0
# class                             0
# first_obs                         0
# last_obs                          0
# diameter_(km)                  5442
# albedo                         5475
# stand_grav_param                  0
# rel_velocity_Q                    0
# rel_velocity_q                    0
# dtype: int64

# %% [markdown]
# Drop columns that are more than 60% of the values.

# %%
# 5442/df.shape[0]

df.drop(columns=['diameter_(km)', 'albedo'], inplace=True)
# Out:
# 0.6927189409368636

# %%
df.dtypes
# Out:
# full_name                              object
# neo                                     int64
# hazardous                               int64
# epoch_cal                             float64
# eccentricity_(e)                      float64
# semi_major_axis_(a)                   float64
# perihelion_dist_(q)                   float64
# inclination_(i)                       float64
# perihelion_arg_(w)                    float64
# abs_magnitude_(H)                     float64
# mean_anomaly                          float64
# aphelion_dist_(Q)                     float64
# mean_motion_(n)                       float64
# min_orbit_intersection_dist           float64
# t_jupiter                             float64
# asc_node_long_(deg)                   float64
# orbital_per_(d)                       float64
# orbital_per_(y)                       float64
# class                                  object
# first_obs                      datetime64[ns]
# last_obs                       datetime64[ns]
# stand_grav_param                      float64
# rel_velocity_Q                        float64
# rel_velocity_q                        float64
# dtype: object

# %%
df.drop(columns=['full_name'], inplace=True)

# %%
df.head()
# Out:
#    neo  hazardous   epoch_cal  eccentricity_(e)  semi_major_axis_(a)  \
# 0    1          0  20200531.0          0.222951             1.458046
# 1    0          0  20200531.0          0.147122             5.209394
# 2    0          0  20200531.0          0.138967             5.214560
# 3    0          0  20200531.0          0.022797             5.262260
# 4    0          0  20200531.0          0.117448             5.164464
#
#    perihelion_dist_(q)  inclination_(i)  perihelion_arg_(w)  \
# 0             1.132973        10.830543          178.882294
# 1             4.442980        10.319724          133.308510
# 2             4.489910        22.051776          307.866082
# 3             5.142298        18.157697          184.243883
# 4             4.557910         4.522630          343.462149
#
#    abs_magnitude_(H)  mean_anomaly  ...  t_jupiter  asc_node_long_(deg)  \
# 0               10.4    271.071732  ...      4.582           304.299327
# 1                8.3    271.736443  ...      2.946           316.536049
# 2                8.2    237.007167  ...      2.836            44.348414
# 3                7.2    202.508492  ...      2.899           342.791035
# 4                8.7     14.898330  ...      2.980           350.739111
#
#    orbital_per_(d)  orbital_per_(y)  class  first_obs   last_obs  \
# 0       643.065402         1.760617    AMO 1893-10-29 2019-02-13
# 1      4342.893776        11.890195    TJN 1906-02-22 2020-01-06
# 2      4349.355185        11.907886    TJN 1998-04-22 2019-08-17
# 3      4409.170054        12.071650    TJN 1907-02-11 2020-01-26
# 4      4286.830857        11.736703    TJN 1908-03-23 2020-01-06
#
#   stand_grav_param rel_velocity_Q rel_velocity_q
# 0         0.818917       2.833825       4.459991
# 1        37.349792      10.952378      14.730948
# 2        37.461014      11.054892      14.623303
# 3        38.498470      12.541588      13.126737
# 4        36.391711      11.190881      14.169385
#
# [5 rows x 23 columns]

# %%
sns.distplot(df['epoch_cal'].unique())

# %%
df['first_obs'].hist(bins=50)

# %%
df['last_obs'].hist(bins=50)

# %%
df['class'].hist()

# %%
cols = list(df.columns)
cols
# Out:
# ['full_name',
#  'neo',
#  'hazardous',
#  'epoch_cal',
#  'eccentricity_(e)',
#  'semi_major_axis_(a)',
#  'perihelion_dist_(q)',
#  'inclination_(i)',
#  'perihelion_arg_(w)',
#  'abs_magnitude_(H)',
#  'mean_anomaly',
#  'aphelion_dist_(Q)',
#  'mean_motion_(n)',
#  'min_orbit_intersection_dist',
#  't_jupiter',
#  'asc_node_long_(deg)',
#  'orbital_per_(d)',
#  'orbital_per_(y)',
#  'class',
#  'first_obs',
#  'last_obs',
#  'stand_grav_param',
#  'rel_velocity_Q',
#  'rel_velocity_q']

# %% [markdown]
# ### Pickle Cleaned and Preprocessed Data

# %%
import pickle

pickle.dump(df, open("../assets/clean_df.pkl", "wb"))
